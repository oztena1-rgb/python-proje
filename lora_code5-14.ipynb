# %%
import numpy as np
import pandas as pd
df=pd.read_excel('column_example.xlsx', header=[0,1], index_col=0)
df=df.round(4)
df.head()
# Out:
# Column Column
# x       M neg   M pos V neg   V pos N neg     N pos
# 0.0000    0.0  0.0000   0.0  0.0000   0.0    0.0000
# 0.0000    0.0  2.9919   0.0  0.5679   0.0  806.8224
# 0.1675    0.0  2.9024   0.0  0.5679   0.0  806.8224
# 0.3350    0.0  2.8133   0.0  0.5678   0.0  806.8224
# 0.5025    0.0  2.7247   0.0  0.5677   0.0  806.8224
