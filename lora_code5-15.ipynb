# %%
import numpy as np
import pandas as pd
df=pd.read_excel('column_example.xlsx',header=[0,1], index_col=0)
df=df.round(4)
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2 import pandas as pd
#       3 df=pd.read_excel('column_example.xlsx',header=[0,1], index_col=0)
# ----> 4 df=df_round(4)
#       5 df.tail()
#
# NameError: name 'df_round' is not defined
