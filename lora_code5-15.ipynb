# %%
import numpy as np
import pandas as pd
df=pd.read_excel('column_example.xlsx',header=[0,1], index_col=0)
df=df.round(4)
df.tail()
# Out:
# Column Column
# x       M neg   M pos V neg   V pos N neg     N pos
# 3.350     0.0  1.3601   0.0  0.5140   0.0  806.8227
# 3.350     0.0  3.0870   0.0  0.6027   0.0  220.7086
# 5.025     0.0  2.1503   0.0  0.6027   0.0  220.7086
# 6.700     0.0  1.3178   0.0  0.6027   0.0  220.7086
# 6.700     NaN     NaN   NaN     NaN   NaN       NaN
