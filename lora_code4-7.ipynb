# %%
import sympy as sp
x, y=sp.symbols("x y")
res1=sp.linsolve([x+y-4, x-y-9], (x, y))
display(res1.args[0])

res2=sp.nonlinsolve([2*x**2+3*x-y-1, 3*x+2*y-5],(x,y))
display(res2)
# Out:
# (13/2, -5/2)
# {(-9/8 + sqrt(193)/8, 67/16 - 3*sqrt(193)/16), (-sqrt(193)/8 - 9/8, 3*sqrt(193)/16 + 67/16)}
