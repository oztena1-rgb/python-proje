# %%
a="Hello"+" World"
b=2+2
print(a)
print("The result of 2+2 is : {0}".format(b))
\begin{codeout}{title=output:}
# Out:
#   Cell In[1], line 5
#     \begin{codeout}-{title=output:}
#      ^
# SyntaxError: unexpected character after line continuation character
