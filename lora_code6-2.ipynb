# %%
import pandas as pd
import numpy as np
data=pd.read_excel("beam.csv.xlsx")
x=np.array(data.x)
M1=np.array(data.M1)
M2=np.array(data.M2)
V1=np.array(data.V1)
V2=np.array(data.V2)
plt.plot(x,M1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       3 data=pd.read_excel("beam.csv.xlsx")
#       4 x=np.array(data.x)
#       5 M1=np.array(data.M1)
#       6 M2=np.array(data.M2)
# ----> 7 V1=np.array(data.v1)
#       8 V2=np.array(data.v2)
#       9 plt.plot(x,M1)
#      10 plt.show()
#
# File c:\Users\Aozte\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'v1'

# %%
import os
print(os.getcwd())
# Out:
# c:\projects\python
