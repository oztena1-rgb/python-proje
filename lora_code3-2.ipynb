# %%
import numpy as np
a=np.array([1,2,3,4])
b=np.array([[1,2],[3.5, 4.2]])
print("a={0}".format(a))
print("b={0}".format(b))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import numpy
# ----> 2 a=np.array([1,2,3,4])
#       3 b=np.array([[1,2],[3.5, 4.2]])
#       4 print("a={0}".format(a))
#       5 print("b={0}".format(b))
#
# NameError: name 'np' is not defined
