# %%
a=[2, 4, 16, 32]
print(a[0]) #prints the first element of a 
a[1]="hello" # assign 'hello' to the second posiion of a
print(a)
b=[[3,6],[9,12]]
print(b[0][1]) #prints element in position 0.1 of b
