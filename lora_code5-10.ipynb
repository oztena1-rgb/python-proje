# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.randint(0,10,(3,5)),
                columns=["a", "b", "c", "d", "e"])
display(df)
display(df.loc[:, "b","d"])
display(df.iloc[2, 3])
