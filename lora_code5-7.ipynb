# %%
import numpy as np
import pandas as pd
df1=pd.Dataframe({"A":[4,2], "B":[9,1]},
            index=["row 1", "row2"])
df2=pd.DataFrame({"A":[5,3], "B":[7,9]},
                 index=["row 3", "row 4"})
res=pd.concat([df1,df2])
res
