# %%
import numpy as np
import pandas as pd
header=pd.MultiIndex.from_tuples([("A", "x"),("A","y"),
                                ("B", "u"), ("B", "v")])
ind=[np.array(["M", "M", "N", "N"]),
     np.array(["bar", "foo", "baz","qux"])]
data=np.array([[9,4,8,5],[4,4,0,1],[5,7,4,5],[6,6,2,2]])
df=pd.DataFrame(data, columns=header,index=ind)
df
# Out:
# <>:7: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:7: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# C:\Users\Aozte\AppData\Local\Temp\ipykernel_30764\1349219975.py:7: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   data=np.array([[9,4,8,5],[4,4,0,1],[5,7,4,5][6,6,2,2]])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 header=pd.MultiIndex.from_tuples([("A", "x"),("A","y"),
#       4                                 ("B", "u"), ("B", "v")])
#       5 ind=[np.array(["M", "M", "N", "N"]),
#       6      np.array(["bar", "foo", "baz","qux"])]
# ----> 7 data=np.array([[9,4,8,5],[4,4,0,1],[5,7,4,5][6,6,2,2]])
#       8 df=pd.DataFrame(data, columns=header,index=ind)
#       9 df
#
# TypeError: list indices must be integers or slices, not tuple
