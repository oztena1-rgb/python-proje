# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(
                {"A": [4, 2, 6], 
                 "B": [9, 1, 8], 
                 "C": [5, 7, 4]},
                index=[1, 2, 3])
df = df.rename(columns={"A": "col. 1", "B": "col. 2", "C": "col. 3"},   
               index={1: "row 1", 2: "row 2", 3: "row 3"}
)              
display(df)
# Out:
#        col. 1  col. 2  col. 3
# row 1       4       9       5
# row 2       2       1       7
# row 3       6       8       4
