# %%
import numpy as np
import pandas as pd
df=df.rename(
    columns={"A":"col. 1", "B":"col. 2", "C":"col. 3"},
    index={1:"row 1", 2:"row 2", 3:"row 3"})

print (df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df=df.rename(columns={"A":"col. 1", "B":"col. 2", "C":"col. 3"},
#       4           index={1:"row 1", 2:"row 2", 3:"row 3"})
#       5
#       6 display (df)
#
# NameError: name 'df' is not defined
