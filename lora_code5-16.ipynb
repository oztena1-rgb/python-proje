# %%
import numpy as np
import pandas as pd
df=pd.read_excel('column_example.xlsx', header=[0,1], index_col=0)
df.columns=df.columns.droplevel(0)
df=df.dropna()
df=df.drop(0)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 df.columns=df.columns.droplevel(0)
#       4 df=df.dropna()
#       5 df=df.drop(0)
#       6 df.head()
#
# NameError: name 'df' is not defined
