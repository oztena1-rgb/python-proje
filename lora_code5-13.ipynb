# %%
import numpy as np
import pandas as pd
b=np.array([1,1,1])
h=np.array([1,2,3])
df=pd.DataFrame({"b":b, "h":h})

df["I"]=(df.b*(df.h)**3)/12
df
# Out:
#    b  h         I
# 0  1  1  0.083333
# 1  1  2  0.666667
# 2  1  3  2.250000
