# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("beam.csv.xlsx")

fig, ax=plt.subplots()
ax.plot(data["x"], M1, label="M1", linewidth=3)
ax.plot(data["x"], M2, label="M2", linewidth=3)

ax.set_xlabel("x (m)")
ax.set_ylabel("Moment")
ax.set_title("Moment Diyagramı")

ax.axhline(0, color="black", linewidth=1)
ax.invert_yaxis()
ax.grid(True)
ax.legend()

plt.show()
# Out:
#   Cell In[1], line 8
#     ax.plot(data["x"], M2, label="M2","linewidth=3)
#                                       ^
# SyntaxError: unterminated string literal (detected at line 8)
