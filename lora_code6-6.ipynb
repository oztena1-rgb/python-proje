# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("beam.csv.xlsx")

fig, ax=plt.subplots()
ax.plot(data["x"], data[M1], label="M1", linewidth=3)
ax.plot(data["x"], data[M2],label="M2", linewidth=3)

ax.set_xlabel("x (m)")
ax.set_ylabel("Moment")
ax.set_title("Moment Diyagramı")

ax.axhline(0, color="black", linewidth=1)
ax.invert_yaxis()
ax.grid(True)
ax.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4 data = pd.read_excel("beam.csv.xlsx")
#       5
#       6 fig, ax=plt.subplots()
# ----> 7 ax.plot(data["x"], M1, label="M1", linewidth=3)
#       8 ax.plot(data["x"], M2, label="M2", linewidth=3)
#       9
#      10 ax.set_xlabel("x (m)")
#
# NameError: name 'M1' is not defined
