# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the Excel file
data = pd.read_excel("beam.csv.xlsx")

fig, ax=plt.subplots(figsize=(8,3))

ax.invert_yaxis()

ax.plot(data["x"],data["M1"],label="M1", color="deeppink", linestyle="--", linewidth=3)
ax.legend()
plt.show()
