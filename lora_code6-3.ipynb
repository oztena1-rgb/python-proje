# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_excel("beam.csv.xlsx")
print(data.columns)


plt.plot(data["x"],M1, label="M1")
plt.xlabel("x")
plt.ylabel("bending moment")
plt.title("Beam")
plt.legend()
plt.gca().invert_yaxis()
plt.gcf().set_size_inches(6, 3)
plt.show()
# Out:
# Index(['x', 'M1', 'V1', 'M2', 'V2'], dtype='str')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       4 data=pd.read_excel("beam.csv.xlsx")
#       5 print(data.columns)
#       6
#       7
# ----> 8 plt.plot(x,M1, label="M1")
#       9 plt.xlabel("x")
#      10 plt.ylabel("bending moment")
#      11 plt.title("Beam")
#
# NameError: name 'x' is not defined

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# c:\projects\python
# ['.git', '1st_graph.py', '2nd_garaph.py', '2nd_garaph_.py', '3rd_graph.py', '4th_graph.py', '5th_graph.py', 'age.py', 'age1.py', 'alien.py', 'alien1.py', 'alp_son.py', 'bar_chart', 'bar_chart_steps.py', 'beam.csv.xlsx', 'beam_example.csv', 'calc_num.py', 'cars.py', 'column_example.xlsx', 'comment.py', 'common.py', 'common_new.py', 'custom_axis.py', 'Deneme.ipynb', 'dimensions.py', 'dimensions1.py', 'even_num.py', 'exceptions&invalid_input.py', 'factors.py', 'factors_if_float.py', 'fibo_seq.py', 'food_append.py', 'food_append1.py', 'format.py', 'for_loop1.py', 'for_loop2.py', 'fractions_notes.py', 'freq_table.py', 'grafik3.py', 'gravity_1.png', 'idle_window.py', 'idle_window_factors.py', 'if_elif_else.py', 'if_elif_else1.py', 'if_elif_else2.py', 'ilk_grafik.py', 'ilk_grafik1.py', 'indentation1.py', 'indentation2.py', 'kong_1.ipynb', 'list.py', 'list_comp.py', 'list_temp_sort.py', 'loop_magicians.py', 'loop_to_exit.py', 'lora_code2-10.ipynb', 'lora_code2-11.ipynb', 'lora_code2-12..ipynb', 'lora_code2-13.ipynb', 'lora_code2-14.ipynb', 'lora_code2-15.ipynb', 'lora_code2-16.ipynb', 'lora_code2-17.ipynb', 'lora_code2-18.ipynb', 'lora_code2-19.ipynb', 'lora_code2-2.ipynb', 'lora_code2-20.ipynb', 'lora_code2-21.ipynb', 'lora_code2-22.ipynb', 'lora_code2-23.ipynb', 'lora_code2-24.ipynb', 'lora_code2-25.ipynb', 'lora_code2-26.ipynb', 'lora_code2-27.ipynb', 'lora_code2-28.ipynb', 'lora_code2-29.ipynb', 'lora_code2-3.ipynb', 'lora_code2-30.ipynb', 'lora_code2-31.ipynb', 'lora_code2-4.ipynb', 'lora_code2-5.ipynb', 'lora_code2-6.ipynb', 'lora_code2-7.ipynb', 'lora_code2-8.ipynb', 'lora_code2-9.ipynb', 'lora_code3-1.ipynb', 'lora_code3-10.ipynb', 'lora_code3-11.ipynb', 'lora_code3-12.ipynb', 'lora_code3-13.ipynb', 'lora_code3-14.ipynb', 'lora_code3-2.ipynb', 'lora_code3-3.ipynb', 'lora_code3-4.ipynb', 'lora_code3-5.ipynb', 'lora_code3-6.ipynb', 'lora_code3-7.ipynb', 'lora_code3-8.ipynb', 'lora_code3-9.ipynb', 'lora_code4-1.ipynb', 'lora_code4-2.ipynb', 'lora_code4-3.ipynb', 'lora_code4-4.ipynb', 'lora_code4-5.ipynb', 'lora_code4-6.ipynb', 'lora_code4-7.ipynb', 'lora_code5-1.ipynb', 'lora_code5-10.ipynb', 'lora_code5-11.ipynb', 'lora_code5-13.ipynb', 'lora_code5-14.ipynb', 'lora_code5-15.ipynb', 'lora_code5-16.ipynb', 'lora_code5-19.ipynb', 'lora_code5-2.ipynb', 'lora_code5-4.ipynb', 'lora_code5-6.ipynb', 'lora_code5-7.ipynb', 'lora_code5-8.ipynb', 'lora_code5-9.ipynb', 'lora_code6-17.ipynb', 'lora_code6-2.ipynb', 'lora_code6-3.ipynb', 'main,py', 'maplotlib.py', 'mean.py', 'median', 'motorcycles.py', 'motorcycles1.py', 'motorcycles2.py', 'multiple_con1.py', 'multiplication_table.py', 'multpl_list.py', 'mult_mode.py', 'mul_table.py', 'myfood_friendfood,py', 'my_numbers.py', 'name', 'name_variables.py', 'newton1', 'omittheelse.py', 'players.py', 'png.py', 'png1.py', 'poping_any_position.py', 'prog_fraction.py', 'pyplot_plt.py', 'pypot.py', 'pyshell.py', 'pyton.py', 'quadratic', 'quadratic.py', 'quad_equation.py', 'rannge_num1.py', 'removeby_value.py', 'removingprefix.py', 'removing_elmt.py', 'removwithpop.py', 'removwithpop1.py', 'removwithpop2.py', 'req_toppings.py', 'slice.py', 'sortalist.py', 'sortreversetrue.py', 'sort_num.py', 'square_numbers.py', 'strippingwhitesp.py', 'title.py', 'titles_graph.py', 'title_messge.py', 'toppings.py', 'toppings1.py', 'toppings2.py', 'toppings3.py', 'toppings4.py', 'toppings5.py', 'trajectory', 'trajectory.p.py', 'unit_conv.py', 'unit_conv_miles-km.py', 'white_space.py', 'wr_over_tuple.py', 'zz.py', '__pycache__']

# %%
import os

for dosya in os.listdir():
    if "beam" in dosya.lower():
        print(repr(dosya))
# Out:
# 'beam.csv - Copy.xlsx'
# 'beam.csv.xlsx'
# 'beam_example.csv'
