# %%
import sympy as sp
x, y=sp.symbols("x y")
f=x**2+y**2+sp.Rational(1,3)*x*y
display(f)
res1=f.subs(x,1)
display(res1)
res2=f.subs([(x,1), (y,5)])
display(res2)
display(res2.evalf(5))
# Out:
# x**2 + x*y/3 + y**2
# y**2 + y/3 + 1
# 83/3
# 27.667
