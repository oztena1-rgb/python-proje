# %%
a=3
b=12
myList=[1,2,3,4,5]

if a in myList:
    print("a is in myList")
else:
    print("a is not in myList")

if b in myList:
    print("b is in myList")
else:
    print("b is not in myList")
# Out:
# a is in myList
# b is not in myList
