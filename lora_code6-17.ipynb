# %%
import numpy as np
import pandas as pd
df=pd.read_csv('beam_example.csv', header=[1])
df=df.round(3)
df=df.dropna()
df=df.reset_index(drop=True)
df=df.drop(0)
df=df.reset_index(drop=True)
df.head()
