# %%
import numpy as np
import pandas as pd
df=pd.DataFrame({"A":[4, 2, 6], "B":[9, 1, 8], "C":[5, 7, 4]},
            index=[1, 2, 3])
display(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 df=pd.DataFrame({"A":[4, 2, 6], "B":[9, 1, 8], "C":[5, 7, 4]},
#       4             index[1, 2, 3])
#       5 display(df)
#
# ModuleNotFoundError: No module named 'pandas'
