# %%
import numpy as np
import pandas as pd
df = pd.DataFrame({"A":[4, 2, 6], "B":[9, 1, 8], "C":[5, 7, 4]},
            index=[1, 2, 3])
display(df)
# Out:
#    A  B  C
# 1  4  9  5
# 2  2  1  7
# 3  6  8  4

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 325.9 kB/s eta 0:00:29
#    -- ------------------------------------- 0.5/9.9 MB 325.9 kB/s eta 0:00:29
#    -- ------------------------------------- 0.5/9.9 MB 325.9 kB/s eta 0:00:29
#    -- ------------------------------------- 0.5/9.9 MB 325.9 kB/s eta 0:00:29
#    --- ------------------------------------ 0.8/9.9 MB 313.4 kB/s eta 0:00:30
# ...
