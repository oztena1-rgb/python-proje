# %%
import numpy as np
a=np.array([1,1])
b=np.array([2,2])
c=np.array([3,3])
print(np.hstack((a,b,c)))
print(np.vstack((a,b,c)))
# Out:
#   Cell In[1], line 7
#     )
#     ^
# IndentationError: unexpected indent
