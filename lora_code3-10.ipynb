# %%
import numpy as np
a=np.linspace(0,10,11)
print a
print(a[2:5])
print(a[1:8:2])
# Out:
#   Cell In[1], line 3
#     print a
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?
