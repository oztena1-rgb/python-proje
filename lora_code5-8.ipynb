# %%
import numpy as np
import pandas as pd
df=pd.DataFrame(np.random.randint(0,10, (3,5)),
                columns=["a", "b", "c", "d", "e"])
df
# Out:
#    a  b  c  d  e
# 0  4  9  2  1  6
# 1  3  4  7  6  6
# 2  7  1  2  9  9
