# %%
def myFunc(radius, perimeter)
area, perimeter=myFunc(4,perimeter=True)
print(area)
print(perimeter)
# Out:
#   Cell In[1], line 1
#     def myFunc(radius, perimeter)
#                                  ^
# SyntaxError: expected ':'
