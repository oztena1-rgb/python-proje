# %%
a=1.0 #this is a floating point number
b=12.345 #this another floathing point number
c=2.4e5 #this is floathing point number
        #specified using scientific notation
print(type(a))
print(c/b)
