# %%
a=1.0 #this is a floathing point number
b=12.345 #this another floathing point number
c=2.4e5 #this is floathing point number
        #specified using scientific motion
print (type(a))
print (c/b)
