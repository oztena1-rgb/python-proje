# %%
import numpy as np
a=np.linspace(1,10,6)
print("a={0}".format(a))
# Out:
#   Cell In[1], line 3
#     print("a={0}".format(a)}
#                            ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '('
